# %%
import torch

USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device('cuda' if USE_CUDA else 'cpu')
print(DEVICE)

BATCH_SIZE = 224
EPOCH = 120

import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder

#transform_base = transforms.Compose([transforms.Resize((64, 64)), transforms.ToTensor()])
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomCrop(170),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.Resize([64, 64]),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.RandomCrop(170),
        transforms.Resize([64, 64]),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
}

train_dataset = ImageFolder(root='../dataset/train', transform=data_transforms['train'])
val_dataset = ImageFolder(root='../dataset/valid', transform=data_transforms['valid'])

from torch.utils.data import DataLoader

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)
# Out:
# cuda

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

class Net(nn.Module):
    def __init__(self):
        
        super(Net, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 32, 3, padding = 1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(32, 64, 3, padding = 1)
        self.conv3 = nn.Conv2d(64, 64, 3, padding = 1)
        
        self.fc1 = nn.Linear(4096, 512)
        self.fc2 = nn.Linear(512, 450)
        
    def forward(self, x):
        
        x = self.conv1(x)
        x = F.relu(x)
        x = self.pool(x)
        x = F.dropout(x, p=0.25, training=self.training)
        
        x = self.conv2(x)
        x = F.relu(x)
        x = self.pool(x)
        x = F.dropout(x, p=0.25, training=self.training)
        
        x = self.conv3(x)
        x = F.relu(x)
        x = self.pool(x)
        x = F.dropout(x, p=0.25, training=self.training)
        
        x = x.view(-1, 4096)
        x = self.fc1(x)
        x = F.relu(x)
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.fc2(x)
        
        return F.log_softmax(x, dim=1)
    
model_base = Net().to(DEVICE)
optimizer = optim.Adam(model_base.parameters(), lr=0.001)

# %%
def train(model, train_loader, optimizer):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(DEVICE), target.to(DEVICE)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()

# %%
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(DEVICE), target.to(DEVICE)
            output = model(data)
            
            
            test_loss += F.cross_entropy(output, target, reduction='sum').item()
            
            
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()
            
        test_loss /= len(test_loader.dataset)
        test_accuracy = 100. * correct / len(test_loader.dataset)
        return test_loss, test_accuracy

# %%
import time
import copy
 
def train_baseline(model ,train_loader, val_loader, optimizer, num_epochs = 30):
    best_acc = 0.0  
    best_model_wts = copy.deepcopy(model.state_dict()) 
 
    for epoch in range(1, num_epochs + 1):
        since = time.time()  
        train(model, train_loader, optimizer)
        train_loss, train_acc = evaluate(model, train_loader) 
        val_loss, val_acc = evaluate(model, val_loader)
        
        if val_acc > best_acc: 
            best_acc = val_acc 
            best_model_wts = copy.deepcopy(model.state_dict())
        
        time_elapsed = time.time() - since 
        print('-------------- epoch {} ----------------'.format(epoch))
        print('train. Loss: {:.4f}, Accuracy: {:.2f}%'.format(train_loss, train_acc))   
        print('valid. Loss: {:.4f}, Accuracy: {:.2f}%'.format(val_loss, val_acc))
        print('Completed in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60)) 
    model.load_state_dict(best_model_wts)  
    return model
 

base = train_baseline(model_base, train_loader, val_loader, optimizer, EPOCH)  	 #(16)
torch.save(base,'baseline.pt')
# Out:
# -------------- epoch 1 ----------------
# train. Loss: 4.6662, Accuracy: 8.08%
# valid. Loss: 4.5492, Accuracy: 8.22%
# Completed in 1m 11s
# -------------- epoch 2 ----------------
# train. Loss: 4.1204, Accuracy: 16.63%
# valid. Loss: 4.0037, Accuracy: 16.71%
# Completed in 1m 11s
# -------------- epoch 3 ----------------
# train. Loss: 3.6776, Accuracy: 22.84%
# valid. Loss: 3.5325, Accuracy: 24.98%
# Completed in 1m 19s
# -------------- epoch 4 ----------------
# train. Loss: 3.4459, Accuracy: 27.42%
# valid. Loss: 3.3161, Accuracy: 27.87%
# Completed in 1m 12s
# valid. Loss: 1.5884, Accuracy: 62.22%
# Completed in 1m 8s
# -------------- epoch 83 ----------------
# train. Loss: 1.8059, Accuracy: 57.20%
# valid. Loss: 1.6455, Accuracy: 59.07%
# Completed in 1m 8s
# -------------- epoch 84 ----------------
# train. Loss: 1.7054, Accuracy: 59.63%
# valid. Loss: 1.6094, Accuracy: 60.53%
# Completed in 1m 9s
# -------------- epoch 85 ----------------
# train. Loss: 1.6847, Accuracy: 59.97%
# valid. Loss: 1.5803, Accuracy: 61.64%
# Completed in 1m 9s
# -------------- epoch 86 ----------------
# train. Loss: 1.7256, Accuracy: 59.31%
# valid. Loss: 1.5906, Accuracy: 61.24%
# Completed in 1m 9s
# -------------- epoch 87 ----------------
# train. Loss: 1.7076, Accuracy: 59.71%
# valid. Loss: 1.5772, Accuracy: 61.20%
# Completed in 1m 6s
# -------------- epoch 88 ----------------
# train. Loss: 1.7783, Accuracy: 58.21%
# valid. Loss: 1.6629, Accuracy: 59.47%
# Completed in 1m 6s
# -------------- epoch 89 ----------------
# train. Loss: 1.7184, Accuracy: 59.27%
# valid. Loss: 1.5906, Accuracy: 61.42%
# Completed in 1m 6s
# -------------- epoch 90 ----------------
# train. Loss: 1.7643, Accuracy: 58.36%
# valid. Loss: 1.6561, Accuracy: 60.22%
# Completed in 1m 6s
# -------------- epoch 91 ----------------
# train. Loss: 1.6493, Accuracy: 60.83%
# valid. Loss: 1.5879, Accuracy: 62.18%
# Completed in 1m 6s
# -------------- epoch 92 ----------------
# train. Loss: 1.7342, Accuracy: 58.92%
# valid. Loss: 1.6110, Accuracy: 61.60%
# Completed in 1m 6s
# -------------- epoch 93 ----------------
# train. Loss: 1.7111, Accuracy: 59.20%
# valid. Loss: 1.5925, Accuracy: 61.91%
# Completed in 1m 9s
# -------------- epoch 94 ----------------
# train. Loss: 1.7035, Accuracy: 59.40%
# valid. Loss: 1.6138, Accuracy: 61.87%
# Completed in 1m 11s
# -------------- epoch 95 ----------------
# train. Loss: 1.6941, Accuracy: 59.81%
# valid. Loss: 1.5891, Accuracy: 61.47%
# Completed in 1m 16s
# -------------- epoch 96 ----------------
# train. Loss: 1.7500, Accuracy: 58.34%
# valid. Loss: 1.6333, Accuracy: 61.51%
# Completed in 1m 12s
# -------------- epoch 97 ----------------
# train. Loss: 1.7414, Accuracy: 58.59%
# valid. Loss: 1.5983, Accuracy: 61.02%
# Completed in 1m 10s
# -------------- epoch 98 ----------------
# train. Loss: 1.6949, Accuracy: 60.08%
# valid. Loss: 1.6135, Accuracy: 60.36%
# Completed in 1m 9s
# -------------- epoch 99 ----------------
# train. Loss: 1.6595, Accuracy: 60.70%
# valid. Loss: 1.5410, Accuracy: 62.71%
# Completed in 1m 9s
# -------------- epoch 100 ----------------
# train. Loss: 1.7122, Accuracy: 59.07%
# valid. Loss: 1.6128, Accuracy: 60.09%
# Completed in 1m 9s
# -------------- epoch 101 ----------------
# train. Loss: 1.7517, Accuracy: 58.68%
# valid. Loss: 1.6435, Accuracy: 60.13%
# Completed in 1m 10s
# -------------- epoch 102 ----------------
# train. Loss: 1.7067, Accuracy: 59.50%
# valid. Loss: 1.5797, Accuracy: 61.56%
# Completed in 1m 10s
# -------------- epoch 103 ----------------
# train. Loss: 1.6744, Accuracy: 60.04%
# valid. Loss: 1.5947, Accuracy: 60.89%
# Completed in 1m 9s
# -------------- epoch 104 ----------------
# train. Loss: 1.7030, Accuracy: 59.94%
# valid. Loss: 1.6006, Accuracy: 60.76%
# Completed in 1m 9s
# -------------- epoch 105 ----------------
# train. Loss: 1.7108, Accuracy: 59.19%
# valid. Loss: 1.6093, Accuracy: 60.53%
# Completed in 1m 10s
# -------------- epoch 106 ----------------
# train. Loss: 1.7667, Accuracy: 58.09%
# valid. Loss: 1.6252, Accuracy: 61.11%
# Completed in 1m 9s
# -------------- epoch 107 ----------------
# train. Loss: 1.6391, Accuracy: 61.02%
# valid. Loss: 1.5529, Accuracy: 62.49%
# Completed in 1m 11s
# -------------- epoch 108 ----------------
# train. Loss: 1.6992, Accuracy: 59.74%
# valid. Loss: 1.5964, Accuracy: 61.73%
# Completed in 1m 9s
# -------------- epoch 109 ----------------
# train. Loss: 1.7248, Accuracy: 59.13%
# valid. Loss: 1.6502, Accuracy: 60.67%
# Completed in 1m 10s
# -------------- epoch 110 ----------------
# train. Loss: 1.7378, Accuracy: 58.82%
# valid. Loss: 1.6199, Accuracy: 61.38%
# Completed in 1m 9s
# -------------- epoch 111 ----------------
# train. Loss: 1.6472, Accuracy: 60.72%
# valid. Loss: 1.5331, Accuracy: 62.09%
# Completed in 1m 8s
# -------------- epoch 112 ----------------
# train. Loss: 1.7380, Accuracy: 58.62%
# valid. Loss: 1.6581, Accuracy: 59.73%
# Completed in 1m 9s
# -------------- epoch 113 ----------------
# train. Loss: 1.6576, Accuracy: 61.03%
# valid. Loss: 1.5551, Accuracy: 62.31%
# Completed in 1m 9s
# -------------- epoch 114 ----------------
# train. Loss: 1.5734, Accuracy: 62.44%
# valid. Loss: 1.4851, Accuracy: 63.20%
# Completed in 1m 9s
# -------------- epoch 115 ----------------
# train. Loss: 1.6776, Accuracy: 60.24%
# valid. Loss: 1.5975, Accuracy: 62.13%
# Completed in 1m 9s
# -------------- epoch 116 ----------------
# train. Loss: 1.6652, Accuracy: 60.46%
# valid. Loss: 1.5661, Accuracy: 62.09%
# Completed in 1m 12s
# -------------- epoch 117 ----------------
# train. Loss: 1.6410, Accuracy: 60.82%
# valid. Loss: 1.5142, Accuracy: 62.67%
# Completed in 1m 10s
# -------------- epoch 118 ----------------
# train. Loss: 1.6946, Accuracy: 60.23%
# valid. Loss: 1.5511, Accuracy: 62.09%
# Completed in 1m 9s
# -------------- epoch 119 ----------------
# train. Loss: 1.6395, Accuracy: 60.77%
# valid. Loss: 1.5494, Accuracy: 62.18%
# Completed in 1m 17s
# -------------- epoch 120 ----------------
# train. Loss: 1.5985, Accuracy: 61.78%
# valid. Loss: 1.5246, Accuracy: 63.29%
# Completed in 1m 17s
